# %% [markdown]
# ---
# title: "Exercise 10: Genetic Correlation"
# subtitle: "Post-GWAS Analysis Course"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     toc-depth: 3
# execute:
#   message: false
#   warning: false
# jupyter: python
# ---
#
# # Overview
#
# This notebook uses LDSC to estimate pairwise genetic correlations between ADHD and other traits. You will read the correlation table, inspect the forest plot, and compare the patterns across trait pairs.
#
# ::: {.callout-note}
# ## Learning goals
# By the end of this notebook, you should be able to:
# - explain what a genetic correlation measures
# - run pairwise LDSC correlation analyses from munged summary statistics
# - interpret the result table and forest plot for evidence of shared genetic architecture
# :::
#
# ::: callout-warning
# You will need the following input files: GWAS sumstats for ADHD, BMI, educational attainment, age at first birth, and depression. Those are available as input data.
# :::

# %% [markdown]
#  ## Table of Contents
#
# * [Set up](#section_1)
# * [Run LDSC to estimate pairwise genetic correlations](#section_2)
# * [Analyse and present results](#section_3)
#   * [Result table](#section_3_1)
#   * [Forest plot](#section_3_2)

# %% [markdown]
# # 1. Set up <a class="anchor" id="section_1"></a>

# %%
import pandas as pd
import numpy as np
import os
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Run LDSC to estimate pairwise genetic correlations <a class="anchor" id="section_2"></a>
#
# During the previous workshop, we have harmonized the sumstats using the munge function, we do not need to repeat that step. We will now use the munged files to calculate genetic correlations between pairs of traits with LDSC. The function we use is very similar to the one we used to calculate SNP-based h2.
# We will calculate the genetic correlation between ADHD and all the other traits.

# %%
#Example of command for ADHD and BMI

command = "ldsc \
--rg input/ldsc/adhd_pgc_2022_munged.sumstats.gz,input/ldsc/bmi_yengo_2018_munged.sumstats.gz \
--ref-ld-chr reference_data/eur_w_ld_chr/ \
--w-ld-chr reference_data/eur_w_ld_chr/ \
--n-blocks 200 \
--out output/ldsc/adhd_bmi_rg" 

os.system(command)
# Out:
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 3.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./ldsc.py \
# --out output/ldsc/adhd_bmi_rg \
# --rg input/ldsc/adhd_pgc_2022_munged.sumstats.gz,input/ldsc/bmi_yengo_2018_munged.sumstats.gz \
# --ref-ld-chr reference_data/eur_w_ld_chr/ \
# --w-ld-chr reference_data/eur_w_ld_chr/
#
# Beginning analysis at Mon Aug 10 13:41:33 2026
# Reading summary statistics from input/ldsc/adhd_pgc_2022_munged.sumstats.gz ...
# RuntimeWarning: compression has no effect when passing a non-binary object as input for file input/ldsc/adhd_pgc_2022_munged.sumstats.gz
# Read summary statistics for 1112499 SNPs.
# Reading reference panel LD Score from reference_data/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# Read reference panel LD Scores for 1290028 SNPs.
# Removing partitioned LD Scores with zero variance.
# Reading regression weight LD Score from reference_data/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# Read regression weight LD Scores for 1290028 SNPs.
# After merging with reference panel LD, 1109029 SNPs remain.
# After merging with regression SNP LD, 1109029 SNPs remain.
# Computing rg for phenotype 2/2
# Reading summary statistics from input/ldsc/bmi_yengo_2018_munged.sumstats.gz ...
# RuntimeWarning: compression has no effect when passing a non-binary object as input for file input/ldsc/bmi_yengo_2018_munged.sumstats.gz
# Read summary statistics for 1217311 SNPs.
# After merging with summary statistics, 1109029 SNPs remain.
# 971690 SNPs with valid alleles.
#
# Heritability of phenotype 1
# ---------------------------
# Total Observed scale h2: 0.1149 (0.0052)
# Lambda GC: 1.3615
# Mean Chi^2: 1.4536
# Intercept: 1.0273 (0.0102)
# Ratio: 0.0603 (0.0224)
#
# Heritability of phenotype 2/2
# -----------------------------
# Total Observed scale h2: 0.5002 (0.0246)
# Lambda GC: 3.7782
# Mean Chi^2: 8.9903
# Intercept: 1.5379 (0.1242)
# Ratio: 0.0673 (0.0155)
#
# Genetic Covariance
# ------------------
# Total Observed scale gencov: -0.0099 (0.0039)
# Mean z1*z2: -0.1047
# Intercept: -0.0086 (0.0122)
#
# Genetic Correlation
# -------------------
# Genetic Correlation: -0.0414 (0.016)
# Z-score: -2.5904
# P: 0.0096
#
#
# Summary of Genetic Correlation Results
#                                          p1                                           p2      rg     se       z      p  h2_obs  h2_obs_se  h2_int  h2_int_se  gcov_int  gcov_int_se
# input/ldsc/adhd_pgc_2022_munged.sumstats.gz input/ldsc/bmi_yengo_2018_munged.sumstats.gz -0.0414 0.0160 -2.5904 0.0096  0.5002     0.0246  1.5379     0.1242   -0.0086       0.0122
#
# Analysis finished at Mon Aug 10 13:41:41 2026
# Total time elapsed: 7.65s
# 0

# %%
#You can now adapt this command to calculate the rg between ADHD and the other traits

#ADHD and educational attainment

command = "ldsc \
--rg input/ldsc/adhd_pgc_2022_munged.sumstats.gz,input/ldsc/educational_attainment_xia_2025_munged.sumstats.gz \
--ref-ld-chr reference_data/eur_w_ld_chr/ \
--w-ld-chr reference_data/eur_w_ld_chr/ \
--n-blocks 200 \
--out output/ldsc/adhd_edu_rg" 

os.system(command)
# Out:
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 3.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./ldsc.py \
# --out output/ldsc/adhd_edu_rg \
# --rg input/ldsc/adhd_pgc_2022_munged.sumstats.gz,input/ldsc/educational_attainment_xia_2025_munged.sumstats.gz \
# --ref-ld-chr reference_data/eur_w_ld_chr/ \
# --w-ld-chr reference_data/eur_w_ld_chr/
#
# Beginning analysis at Mon Aug 10 13:44:10 2026
# Reading summary statistics from input/ldsc/adhd_pgc_2022_munged.sumstats.gz ...
# RuntimeWarning: compression has no effect when passing a non-binary object as input for file input/ldsc/adhd_pgc_2022_munged.sumstats.gz
# Read summary statistics for 1112499 SNPs.
# Reading reference panel LD Score from reference_data/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# Read reference panel LD Scores for 1290028 SNPs.
# Removing partitioned LD Scores with zero variance.
# Reading regression weight LD Score from reference_data/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# Read regression weight LD Scores for 1290028 SNPs.
# After merging with reference panel LD, 1109029 SNPs remain.
# After merging with regression SNP LD, 1109029 SNPs remain.
# Computing rg for phenotype 2/2
# Reading summary statistics from input/ldsc/educational_attainment_xia_2025_munged.sumstats.gz ...
# RuntimeWarning: compression has no effect when passing a non-binary object as input for file input/ldsc/educational_attainment_xia_2025_munged.sumstats.gz
# Read summary statistics for 1217311 SNPs.
# After merging with summary statistics, 1109029 SNPs remain.
# 1006540 SNPs with valid alleles.
#
# Heritability of phenotype 1
# ---------------------------
# Total Observed scale h2: 0.112 (0.0057)
# Lambda GC: 1.3789
# Mean Chi^2: 1.4733
# Intercept: 1.04 (0.0117)
# Ratio: 0.0846 (0.0248)
#
# Heritability of phenotype 2/2
# -----------------------------
# Total Observed scale h2: 0.1174 (0.0037)
# Lambda GC: 2.3096
# Mean Chi^2: 2.9266
# Intercept: 1.072 (0.0243)
# Ratio: 0.0374 (0.0126)
#
# Genetic Covariance
# ------------------
# Total Observed scale gencov: -0.0599 (0.0029)
# Mean z1*z2: -0.495
# Intercept: -0.0282 (0.0107)
#
# Genetic Correlation
# -------------------
# Genetic Correlation: -0.5218 (0.0203)
# Z-score: -25.7381
# P: 4.3834e-146
#
#
# Summary of Genetic Correlation Results
#                                          p1                                                            p2      rg     se        z      p  h2_obs  h2_obs_se  h2_int  h2_int_se  gcov_int  gcov_int_se
# input/ldsc/adhd_pgc_2022_munged.sumstats.gz input/ldsc/educational_attainment_xia_2025_munged.sumstats.gz -0.5218 0.0203 -25.7381 0.0000  0.1174     0.0037  1.0720     0.0243   -0.0282       0.0107
#
# Analysis finished at Mon Aug 10 13:44:17 2026
# Total time elapsed: 7.58s
# 0

# %%
#ADHD and Year at first birth

command = "ldsc \
--rg input/ldsc/adhd_pgc_2022_munged.sumstats.gz,input/ldsc/year_at_first_birth_mills_2020_munged.sumstats.gz \
--ref-ld-chr reference_data/eur_w_ld_chr/ \
--w-ld-chr reference_data/eur_w_ld_chr/ \
--n-blocks 200 \
--out output/ldsc/adhd_yearfb_rg" 

os.system(command)
# Out:
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 3.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./ldsc.py \
# --out output/ldsc/adhd_yearfb_rg \
# --rg input/ldsc/adhd_pgc_2022_munged.sumstats.gz,input/ldsc/year_at_first_birth_mills_2020_munged.sumstats.gz \
# --ref-ld-chr reference_data/eur_w_ld_chr/ \
# --w-ld-chr reference_data/eur_w_ld_chr/
#
# Beginning analysis at Mon Aug 10 13:44:56 2026
# Reading summary statistics from input/ldsc/adhd_pgc_2022_munged.sumstats.gz ...
# RuntimeWarning: compression has no effect when passing a non-binary object as input for file input/ldsc/adhd_pgc_2022_munged.sumstats.gz
# Read summary statistics for 1112499 SNPs.
# Reading reference panel LD Score from reference_data/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# Read reference panel LD Scores for 1290028 SNPs.
# Removing partitioned LD Scores with zero variance.
# Reading regression weight LD Score from reference_data/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# Read regression weight LD Scores for 1290028 SNPs.
# After merging with reference panel LD, 1109029 SNPs remain.
# After merging with regression SNP LD, 1109029 SNPs remain.
# Computing rg for phenotype 2/2
# Reading summary statistics from input/ldsc/year_at_first_birth_mills_2020_munged.sumstats.gz ...
# RuntimeWarning: compression has no effect when passing a non-binary object as input for file input/ldsc/year_at_first_birth_mills_2020_munged.sumstats.gz
# Read summary statistics for 1217311 SNPs.
# After merging with summary statistics, 1109029 SNPs remain.
# 1106973 SNPs with valid alleles.
#
# Heritability of phenotype 1
# ---------------------------
# Total Observed scale h2: 0.1144 (0.0054)
# Lambda GC: 1.3581
# Mean Chi^2: 1.4501
# Intercept: 1.0282 (0.0095)
# Ratio: 0.0627 (0.0212)
#
# Heritability of phenotype 2/2
# -----------------------------
# Total Observed scale h2: 0.0331 (0.0014)
# Lambda GC: 1.4853
# Mean Chi^2: 1.6379
# Intercept: 1.0246 (0.0118)
# Ratio: 0.0385 (0.0184)
#
# Genetic Covariance
# ------------------
# Total Observed scale gencov: -0.0404 (0.002)
# Mean z1*z2: -0.3598
# Intercept: -0.0233 (0.008)
#
# Genetic Correlation
# -------------------
# Genetic Correlation: -0.6562 (0.0227)
# Z-score: -28.9097
# P: 9.0222e-184
#
#
# Summary of Genetic Correlation Results
#                                          p1                                                           p2      rg     se        z      p  h2_obs  h2_obs_se  h2_int  h2_int_se  gcov_int  gcov_int_se
# input/ldsc/adhd_pgc_2022_munged.sumstats.gz input/ldsc/year_at_first_birth_mills_2020_munged.sumstats.gz -0.6562 0.0227 -28.9097 0.0000  0.0331     0.0014  1.0246     0.0118   -0.0233       0.0080
#
# Analysis finished at Mon Aug 10 13:45:03 2026
# Total time elapsed: 7.69s
# 0

# %%
#ADHD and Depression

command = "ldsc \
--rg input/ldsc/adhd_pgc_2022_munged.sumstats.gz,input/ldsc/depression_pgc_2025_munged.sumstats.gz \
--ref-ld-chr reference_data/eur_w_ld_chr/ \
--w-ld-chr reference_data/eur_w_ld_chr/ \
--n-blocks 200 \
--out output/ldsc/adhd_depression_rg" 

os.system(command)
# Out:
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 3.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./ldsc.py \
# --out output/ldsc/adhd_depression_rg \
# --rg input/ldsc/adhd_pgc_2022_munged.sumstats.gz,input/ldsc/depression_pgc_2025_munged.sumstats.gz \
# --ref-ld-chr reference_data/eur_w_ld_chr/ \
# --w-ld-chr reference_data/eur_w_ld_chr/
#
# Beginning analysis at Mon Aug 10 13:45:38 2026
# Reading summary statistics from input/ldsc/adhd_pgc_2022_munged.sumstats.gz ...
# RuntimeWarning: compression has no effect when passing a non-binary object as input for file input/ldsc/adhd_pgc_2022_munged.sumstats.gz
# Read summary statistics for 1112499 SNPs.
# Reading reference panel LD Score from reference_data/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# Read reference panel LD Scores for 1290028 SNPs.
# Removing partitioned LD Scores with zero variance.
# Reading regression weight LD Score from reference_data/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# Read regression weight LD Scores for 1290028 SNPs.
# After merging with reference panel LD, 1109029 SNPs remain.
# After merging with regression SNP LD, 1109029 SNPs remain.
# Computing rg for phenotype 2/2
# Reading summary statistics from input/ldsc/depression_pgc_2025_munged.sumstats.gz ...
# RuntimeWarning: compression has no effect when passing a non-binary object as input for file input/ldsc/depression_pgc_2025_munged.sumstats.gz
# Read summary statistics for 1217311 SNPs.
# After merging with summary statistics, 1109029 SNPs remain.
# 1046874 SNPs with valid alleles.
#
# Heritability of phenotype 1
# ---------------------------
# Total Observed scale h2: 0.1138 (0.0052)
# Lambda GC: 1.3581
# Mean Chi^2: 1.4478
# Intercept: 1.03 (0.0099)
# Ratio: 0.067 (0.022)
#
# Heritability of phenotype 2/2
# -----------------------------
# Total Observed scale h2: 0.0518 (0.0016)
# Lambda GC: 1.8809
# Mean Chi^2: 2.2293
# Intercept: 1.058 (0.0157)
# Ratio: 0.0471 (0.0128)
#
# Genetic Covariance
# ------------------
# Total Observed scale gencov: 0.0458 (0.002)
# Mean z1*z2: 0.5434
# Intercept: 0.127 (0.009)
#
# Genetic Correlation
# -------------------
# Genetic Correlation: 0.5961 (0.0177)
# Z-score: 33.6323
# P: 5.6613e-248
#
#
# Summary of Genetic Correlation Results
#                                          p1                                                p2     rg     se       z      p  h2_obs  h2_obs_se  h2_int  h2_int_se  gcov_int  gcov_int_se
# input/ldsc/adhd_pgc_2022_munged.sumstats.gz input/ldsc/depression_pgc_2025_munged.sumstats.gz 0.5961 0.0177 33.6323 0.0000  0.0518     0.0016  1.0580     0.0157    0.1270       0.0090
#
# Analysis finished at Mon Aug 10 13:45:46 2026
# Total time elapsed: 7.69s
# 0

# %% [markdown]
# ## 3. Analyse and present results <a class="anchor" id="section_3"></a>
#
# You now have calculated the SNP-based heritability for each of the trait. We will extract that information from the log file, and present the results.

# %% [markdown]
# ### 3.1 Result table <a class="anchor" id="section_3_1"></a>
# If you open the log files generated in the previous section, you can see that they contain a lot of information, including the genetic correlation (rg) that we will extract for each pair of traits and present in a table.

# %%
#Create a list with the file paths ----> Adapt this section based on how you named the files
path_list = ["output/ldsc/adhd_bmi_rg.log", 
             "output/ldsc/adhd_edu_rg.log", 
             "output/ldsc/adhd_yearfb_rg.log", 
             "output/ldsc/adhd_depression_rg.log"]

#Create a list of trait names
trait_list = ["bmi", "educational_attainment", "year_first_birth", "depression"]

#Initiate an empty list 
rows = []

#We iterate over all the files 
for i in range(len(path_list)):
    
    #Initiate the result vector
    data = {
        "trait1": "adhd",
        "trait2": trait_list[i],
        "rg": None,
        "se": None,
        "p-value": None
    }

    # Read the file and extract rg, se and p-value
    with open(path_list[i], "r") as f:
        for j, line in enumerate(f):
            if j == 54:
                words = line.strip().split()
                
                # Extract 3th and 4th "words" (indices 2 and 3) -> corresponds to rg and se
                data["rg"] = float(words[2]) 
                data["se"] = float(words[3].strip("()"))

            elif j == 56:
                words = line.strip().split()

                #Extract the 2nd "word" (indice 1) -> corresponds to the p-value
                data["p-value"] = float(words[1])

                break # no need to continue reading the file

        #Store in rows
        rows.append(data)
    
   
        
# Store in a DataFrame
df = pd.DataFrame(rows)

df
# Out:
#   trait1                  trait2      rg      se        p-value
# 0   adhd                     bmi -0.0414  0.0160   9.600000e-03
# 1   adhd  educational_attainment -0.5218  0.0203  4.383400e-146
# 2   adhd        year_first_birth -0.6562  0.0227  9.022200e-184
# 3   adhd              depression  0.5961  0.0177  5.661300e-248

# %% [markdown]
# ### 3.2 Present results in a figure <a class="anchor" id="section_3_2"></a>
#
# From the table we just created, we can now create a figure to represent the results. A common way of representing rg is to use a forest plot.

# %%
#Create plot 
fig,ax = plt.subplots(figsize=(6,4))

#Error bars -> SE
ax.errorbar(
    df["rg"], 
    df["trait2"], 
    xerr=[abs(df["rg"]-df["se"]), abs(df["rg"]-df["se"])], 
    fmt='o', 
    color='black', 
)

#Vertical line at 0
ax.axvline(0, color='black', linestyle='--')

#Labels on the y-axis
ax.set_yticklabels(df['trait2'])

#Labels on x-axis
ax.set_xlabel("Genetic correlation")

#Add p-value on the right
for i, (_, row) in enumerate(df.iterrows()):
    ax.text(
        row["rg"] + row["se"] + 0.03,
        i,
        f"p={row['p-value']:.2e}",
        va='bottom',
        fontsize=8
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ::: callout-note
# Based on the result table and the figure, answer the following questions
#
# - Are the results in line with what you expect/the literature?
#
# - Do we need to consider multiple testing? What method can be applied to correct for it? Does it impact the results here?
# :::
